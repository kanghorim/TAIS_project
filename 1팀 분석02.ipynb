# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
df = pd.read_excel('TACHART.xlsx')

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#        발생년도  발생월 발생시간  사망자수  중상자수  경상자수  부상신고자수 발생지_시도 발생지_시군구   법정동명  \
# 0      2019    1  00시     0     0     1       0     서울     강서구    방화동
# 1      2019    1  00시     0     0     1       0     서울     구로구    고척동
# 2      2019    1  00시     0     0     1       0     서울     서초구    서초동
# 3      2019    1  01시     0     0     1       0     서울      중구  회현동2가
# 4      2019    1  01시     0     0     1       0     서울     성동구    행당동
# ...     ...  ...  ...   ...   ...   ...     ...    ...     ...    ...
# 38131  2019   12  22시     0     0     0       1     서울     중랑구    면목동
# 38132  2019   12  22시     0     0     1       0     서울     강남구    삼성동
# 38133  2019   12  22시     0     0     1       0     서울     송파구    송파동
# 38134  2019   12  23시     0     0     0       2     서울     강남구    역삼동
# 38135  2019   12  23시     0     0     1       0     서울     강남구    수서동
#
#       도로형태_대분류 노면상태 기상상태 가해자성별 가해자연령 피해자성별 피해자연령
# 0          교차로   건조   맑음     남   26세     남   40세
# ...

# %% [markdown]
# # 월별 사고율 시각화

# %%
df_gb = df.groupby('발생월').count()

# %%
plt.rc('font', family='Malgun Gothic') 
df_gb = df.groupby('발생지_시군구').count()
df_gb.plot.bar()
plt.show()

# %%
plt.title('산점도')
plt.xlabel('변수1')
plt.ylabel('변수2')
plt.grid(True)
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df_mon_gb = df.groupby('발생월').count()

# %%
[model].sort_values(ascending=False)
